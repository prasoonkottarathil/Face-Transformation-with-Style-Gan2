# %% [markdown]
# ## Warning: This Module Requires TensorFlow 1.x
#
# This module makes use of the nVidia StyleGAN2 package.  Neither StyleGAN 1.0 nor StyleGAN 2.0 currently supports TensorFlow 2.0.  Because of this incompatibility, it will be necessary to run this code with an older version of TensorFlow.  Running this notebook in this way is easiest with Google CoLab.  Because of this, I designed this module to run in Google CoLab.  It will take some modifications to if you wish to run it locally.
#
# Also, note that this module uses StyleGAN 1.0, I will soon update to 2.0.

# %% [markdown]
# Face Generation with StyleGAN2 and Python3
#
# GANs have showed up every now and again in the media, exhibiting their capacity to create amazingly photorealistic faces. One noteworthy advance forward for reasonable face age was nVidia StyleGAN, which was presented in the accompanying paper.
#
# * Karras, T., Laine, S., & Aila, T. (2018). [A style-based generator architecture for generative adversarial networks](https://arxiv.org/abs/1812.04948). *arXiv preprint arXiv:1812.04948*.
#
# * Karras, T., Laine, S., Aittala, M., Hellsten, J., Lehtinen, J., & Aila, T. (2019). [Analyzing and improving the image quality of stylegan](https://arxiv.org/abs/1912.04958). *arXiv preprint arXiv:1912.04958*.
#
# In this part we will utilize StyleGAN2. We will likewise preload loads  weights that nVidia prepared on. This will permit us to create high resolution photorealistic looking faces, for example, these.
#
# The above images were generated with StyleGAN2, using Google CoLab.  Following the instructions in this section, you will be able to create faces like this of your own.  StyleGAN2 images are usually 1,024 x 1,024 in resolution.

# %% [markdown]
# ### Keras Sequence vs Functional Model API
#
# Most of the neural networks create in this course have made use of the Keras sequence object.  You might have noticed that we briefly made use of another type of neural network object for the ResNet, the Model.  These are the [two major means](https://keras.io/getting-started/functional-api-guide/) of constructing a neural network in Keras:
#
# * [Sequential](https://keras.io/getting-started/sequential-model-guide/) - Simplified interface to Keras that supports most models where the flow of information is a simple sequence from input to output.
# * [Keras Functional API](https://keras.io/getting-started/functional-api-guide/) - More complex interface that allows neural networks to be constructed of reused layers, multiple input layers, and supports building your own recurrent connections.
#
# It is important to point out that these are not two specific types of neural network.  Rather, they are two means of constructing neural networks in Keras.  Some types of neural network can be implemented in either, such as dense feedforward neural networks (like we used for the Iris and MPG datasets).  However, other types of neural network, like ResNet and GANs can only be used in the Functional Model API.

# %% [markdown]
# ### Generating High Rez GAN Faces with Google CoLab
#
# This notebook demonstrates how to run [NVidia StyleGAN2](https://github.com/NVlabs/stylegan) inside of a Google CoLab notebook.  I suggest you use this to generate GAN faces from a pretrained model.  If you try to train your own, you will run into compute limitations of Google CoLab.
#
# Make sure to run this code on a GPU instance.  GPU is assumed.
#
# First, map your G-Drive, this is where your GANs will be written to.

# %%
# Run this for Google CoLab (use TensorFlow 1.x)
# %tensorflow_version 1.x
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Next, clone StyleGAN2 from GitHub.

# %%
# !git clone https://github.com/NVlabs/stylegan2.git
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 93, done.
# remote: Total 93 (delta 0), reused 0 (delta 0), pack-reused 93
# Unpacking objects: 100% (93/93), done.

# %% [markdown]
# Verify that StyleGAN has been cloned.

# %%
# !ls /content/stylegan2/
# Out:
# dataset_tool.py  LICENSE.txt		 README.md	   run_training.py
# dnnlib		 metrics		 run_generator.py  test_nvcc.cu
# Dockerfile	 pretrained_networks.py  run_metrics.py    training
# docs		 projector.py		 run_projector.py

# %% [markdown]
# # Run StyleGan2 From Command Line

# %% [markdown]
# Add the StyleGAN folder to Python so that you can import it.  The code below is based on code from NVidia. This actually generates your images.

# %%
# !python /content/stylegan2/run_generator.py generate-images --network=gdrive:networks/stylegan2-ffhq-config-f.pkl \
  --seeds=6600-6625 --truncation-psi=0.5
# Out:
# Local submit - run_dir: results/00002-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "gdrive:networks/stylegan2-ffhq-config-f.pkl"...
# 2020-02-27 09:12:54.384226: W tensorflow/compiler/xla/service/platform_util.cc:256] unable to create StreamExecutor for CUDA:0: failed initializing StreamExecutor for CUDA device ordinal 0: Internal: failed call to cuDevicePrimaryCtxRetain: CUDA_ERROR_OUT_OF_MEMORY: out of memory; total memory reported: 7981694976
# 2020-02-27 09:12:54.384591: F tensorflow/stream_executor/lib/statusor.cc:34] Attempting to fetch value instead of handling error Internal: no supported devices found for platform CUDA

# %%
# !ls /content/results/00000-generate-images
# Out:
# _finished.txt  seed6604.png  seed6611.png  seed6618.png  seed6625.png
# log.txt        seed6605.png  seed6612.png  seed6619.png  submit_config.pkl
# run.txt        seed6606.png  seed6613.png  seed6620.png  submit_config.txt
# seed6600.png   seed6607.png  seed6614.png  seed6621.png
# seed6601.png   seed6608.png  seed6615.png  seed6622.png
# seed6602.png   seed6609.png  seed6616.png  seed6623.png
# seed6603.png   seed6610.png  seed6617.png  seed6624.png

# %%
cp /content/results/00000-generate-images/* /content/drive/My\ Drive/projects/stylegan2
# Out:
# cp: target '/content/drive/My Drive/projects/stylegan2' is not a directory

# %%
# !python /content/stylegan2/run_generator.py style-mixing-example --network=gdrive:networks/stylegan2-ffhq-config-f.pkl \
  --row-seeds=85,100,75,458,1500 --col-seeds=55,821,1789,293 --truncation-psi=1.0
# Out:
# Local submit - run_dir: results/00003-style-mixing-example
# dnnlib: Running run_generator.style_mixing_example() on localhost...
# Loading networks from "gdrive:networks/stylegan2-ffhq-config-f.pkl"...
# 2020-02-27 09:13:04.253721: W tensorflow/compiler/xla/service/platform_util.cc:256] unable to create StreamExecutor for CUDA:0: failed initializing StreamExecutor for CUDA device ordinal 0: Internal: failed call to cuDevicePrimaryCtxRetain: CUDA_ERROR_OUT_OF_MEMORY: out of memory; total memory reported: 7981694976
# 2020-02-27 09:13:04.253983: F tensorflow/stream_executor/lib/statusor.cc:34] Attempting to fetch value instead of handling error Internal: no supported devices found for platform CUDA

# %% [markdown]
# # Run StyleGAN2 From Python Code
#
# Add the StyleGAN folder to Python so that you can import it.  The code below is based on code from NVidia. This actually generates your images.

# %%
import sys
sys.path.insert(0, "/content/stylegan2")

import dnnlib

# %%
# Copyright (c) 2019, NVIDIA Corporation. All rights reserved.
#
# This work is made available under the Nvidia Source Code License-NC.
# To view a copy of this license, visit
# https://nvlabs.github.io/stylegan2/license.html

import argparse
import numpy as np
import PIL.Image
import dnnlib
import dnnlib.tflib as tflib
import re
import sys

import pretrained_networks

#----------------------------------------------------------------------------

def expand_seed(seeds, vector_size):
  result = []

  for seed in seeds:
    rnd = np.random.RandomState(seed)
    result.append( rnd.randn(1, vector_size) ) 
  return result

def generate_images(Gs, seeds, truncation_psi):
    noise_vars = [var for name, var in Gs.components.synthesis.vars.items() if name.startswith('noise')]

    Gs_kwargs = dnnlib.EasyDict()
    Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
    Gs_kwargs.randomize_noise = False
    if truncation_psi is not None:
        Gs_kwargs.truncation_psi = truncation_psi

    for seed_idx, seed in enumerate(seeds):
        print('Generating image for seed %d/%d ...' % (seed_idx, len(seeds)))
        rnd = np.random.RandomState()
        tflib.set_vars({var: rnd.randn(*var.shape.as_list()) for var in noise_vars}) # [height, width]
        images = Gs.run(seed, None, **Gs_kwargs) # [minibatch, height, width, channel]
        path = f"/content/drive/My Drive/projects/stylegan24/image{seed_idx}.png"
        PIL.Image.fromarray(images[0], 'RGB').save(path)

def main():
    sc = dnnlib.SubmitConfig()
    sc.num_gpus = 1
    sc.submit_target = dnnlib.SubmitTarget.LOCAL
    sc.local.do_not_copy_source_files = True
    sc.run_dir_root = "/content/drive/My Drive/projects/stylegan24"
    sc.run_desc = 'generate-images'
    network_pkl = 'gdrive:networks/stylegan2-ffhq-config-f.pkl'

    print('Loading networks from "%s"...' % network_pkl)
    _G, _D, Gs = pretrained_networks.load_networks(network_pkl)
    vector_size = Gs.input_shape[1:][0]
    seeds = expand_seed( range(4100,4120), vector_size)
    generate_images(Gs, seeds,truncation_psi=0.5)

#----------------------------------------------------------------------------

if __name__ == "__main__":
    main()

#----------------------------------------------------------------------------
# Out:
# Loading networks from "gdrive:networks/stylegan2-ffhq-config-f.pkl"...
# Downloading http://d36zk2xti64re0.cloudfront.net/stylegan2/networks/stylegan2-ffhq-config-f.pkl ... done
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Compiling... Loading... Done.
# Generating image for seed 0/20 ...
# Generating image for seed 1/20 ...
# Generating image for seed 2/20 ...
# Generating image for seed 3/20 ...
# Generating image for seed 4/20 ...
# Generating image for seed 5/20 ...
# Generating image for seed 6/20 ...
# Generating image for seed 7/20 ...
# Generating image for seed 8/20 ...
# Generating image for seed 9/20 ...
# Generating image for seed 10/20 ...
# Generating image for seed 11/20 ...
# Generating image for seed 12/20 ...
# Generating image for seed 13/20 ...
# Generating image for seed 14/20 ...
# Generating image for seed 15/20 ...
# Generating image for seed 16/20 ...
# Generating image for seed 17/20 ...
# Generating image for seed 18/20 ...
# Generating image for seed 19/20 ...

# %% [markdown]
# ## Examining the Latent Vector

# %%
sc = dnnlib.SubmitConfig()
sc.num_gpus = 1
sc.submit_target = dnnlib.SubmitTarget.LOCAL
sc.local.do_not_copy_source_files = True
sc.run_dir_root = "/content/drive/My Drive/projects/stylegan25"
sc.run_desc = 'generate-images'
network_pkl = 'gdrive:networks/stylegan2-ffhq-config-f.pkl'

print('Loading networks from "%s"...' % network_pkl)
_G, _D, Gs = pretrained_networks.load_networks(network_pkl)
vector_size = Gs.input_shape[1:][0]
# range(8192,8300)
seeds = expand_seed( [8200+1,8600+9], vector_size)
#generate_images(Gs, seeds,truncation_psi=0.5)
print(seeds[0].shape)
# Out:
# Loading networks from "gdrive:networks/stylegan2-ffhq-config-f.pkl"...
# (1, 512)

# %%
# 8192+1,8192+9

STEPS = 1000
diff = seeds[1] - seeds[0]
step = diff / STEPS
current = seeds[0].copy()

seeds2 = []
for i in range(STEPS):
  seeds2.append(current)
  current = current + step

generate_images(Gs, seeds2,truncation_psi=0.5)
# Out:
# Generating image for seed 0/1000 ...
# Generating image for seed 1/1000 ...
# Generating image for seed 2/1000 ...
# Generating image for seed 3/1000 ...
# Generating image for seed 4/1000 ...
# Generating image for seed 5/1000 ...
# Generating image for seed 6/1000 ...
# Generating image for seed 7/1000 ...
# Generating image for seed 8/1000 ...
# Generating image for seed 9/1000 ...
# Generating image for seed 10/1000 ...
# Generating image for seed 11/1000 ...
# Generating image for seed 12/1000 ...
# Generating image for seed 13/1000 ...
# Generating image for seed 14/1000 ...
# Generating image for seed 15/1000 ...
# Generating image for seed 16/1000 ...
# Generating image for seed 17/1000 ...
# Generating image for seed 18/1000 ...
# Generating image for seed 19/1000 ...
# Generating image for seed 20/1000 ...
# Generating image for seed 21/1000 ...
# Generating image for seed 22/1000 ...
# Generating image for seed 23/1000 ...
# Generating image for seed 24/1000 ...
# Generating image for seed 25/1000 ...
# Generating image for seed 26/1000 ...
# Generating image for seed 27/1000 ...
# Generating image for seed 28/1000 ...
# Generating image for seed 29/1000 ...
# Generating image for seed 30/1000 ...
# Generating image for seed 31/1000 ...
# Generating image for seed 32/1000 ...
# Generating image for seed 33/1000 ...
# Generating image for seed 34/1000 ...
# Generating image for seed 35/1000 ...
# Generating image for seed 36/1000 ...
# Generating image for seed 37/1000 ...
# Generating image for seed 38/1000 ...
# Generating image for seed 39/1000 ...
# Generating image for seed 40/1000 ...
# Generating image for seed 41/1000 ...
# Generating image for seed 42/1000 ...
# Generating image for seed 43/1000 ...
# Generating image for seed 44/1000 ...
# Generating image for seed 45/1000 ...
# Generating image for seed 46/1000 ...
# Generating image for seed 47/1000 ...
# Generating image for seed 48/1000 ...
# Generating image for seed 49/1000 ...
# Generating image for seed 50/1000 ...
# Generating image for seed 51/1000 ...
# Generating image for seed 52/1000 ...
# Generating image for seed 53/1000 ...
# Generating image for seed 54/1000 ...
# Generating image for seed 55/1000 ...
# Generating image for seed 56/1000 ...
# Generating image for seed 57/1000 ...
# Generating image for seed 58/1000 ...
# Generating image for seed 59/1000 ...
# Generating image for seed 60/1000 ...
# Generating image for seed 61/1000 ...
# Generating image for seed 62/1000 ...
# Generating image for seed 63/1000 ...
# Generating image for seed 64/1000 ...
# Generating image for seed 65/1000 ...
# Generating image for seed 66/1000 ...
# Generating image for seed 67/1000 ...
# Generating image for seed 68/1000 ...
# Generating image for seed 69/1000 ...
# Generating image for seed 70/1000 ...
# Generating image for seed 71/1000 ...
# Generating image for seed 72/1000 ...
# Generating image for seed 73/1000 ...
# Generating image for seed 74/1000 ...
# Generating image for seed 75/1000 ...
# Generating image for seed 76/1000 ...
# Generating image for seed 77/1000 ...
# Generating image for seed 78/1000 ...
# Generating image for seed 79/1000 ...
# Generating image for seed 80/1000 ...
# Generating image for seed 81/1000 ...
# Generating image for seed 82/1000 ...
# Generating image for seed 83/1000 ...
# Generating image for seed 84/1000 ...
# Generating image for seed 85/1000 ...
# Generating image for seed 86/1000 ...
# Generating image for seed 87/1000 ...
# Generating image for seed 88/1000 ...
# Generating image for seed 89/1000 ...
# Generating image for seed 90/1000 ...
# Generating image for seed 91/1000 ...
# Generating image for seed 92/1000 ...
# Generating image for seed 93/1000 ...
# Generating image for seed 94/1000 ...
# Generating image for seed 95/1000 ...
# Generating image for seed 96/1000 ...
# Generating image for seed 97/1000 ...
# Generating image for seed 98/1000 ...
# Generating image for seed 99/1000 ...
# Generating image for seed 100/1000 ...
# Generating image for seed 101/1000 ...
# Generating image for seed 102/1000 ...
# Generating image for seed 103/1000 ...
# Generating image for seed 104/1000 ...
# Generating image for seed 105/1000 ...
# Generating image for seed 106/1000 ...
# Generating image for seed 107/1000 ...
# Generating image for seed 108/1000 ...
# Generating image for seed 109/1000 ...
# Generating image for seed 110/1000 ...
# Generating image for seed 111/1000 ...
# Generating image for seed 112/1000 ...
# Generating image for seed 113/1000 ...
# Generating image for seed 114/1000 ...
# Generating image for seed 115/1000 ...
# Generating image for seed 116/1000 ...
# Generating image for seed 117/1000 ...
# Generating image for seed 118/1000 ...
# Generating image for seed 119/1000 ...
# Generating image for seed 120/1000 ...
# Generating image for seed 121/1000 ...
# Generating image for seed 122/1000 ...
# Generating image for seed 123/1000 ...
# Generating image for seed 124/1000 ...
# Generating image for seed 125/1000 ...
# Generating image for seed 126/1000 ...
# Generating image for seed 127/1000 ...
# Generating image for seed 128/1000 ...
# Generating image for seed 129/1000 ...
# Generating image for seed 130/1000 ...
# Generating image for seed 131/1000 ...
# Generating image for seed 132/1000 ...
# Generating image for seed 133/1000 ...
# Generating image for seed 134/1000 ...
# Generating image for seed 135/1000 ...
# Generating image for seed 136/1000 ...
# Generating image for seed 137/1000 ...
# Generating image for seed 138/1000 ...
# Generating image for seed 139/1000 ...
# Generating image for seed 140/1000 ...
# Generating image for seed 141/1000 ...
# Generating image for seed 142/1000 ...
# Generating image for seed 143/1000 ...
# Generating image for seed 144/1000 ...
# Generating image for seed 145/1000 ...
# Generating image for seed 146/1000 ...
# Generating image for seed 147/1000 ...
# Generating image for seed 148/1000 ...
# Generating image for seed 149/1000 ...
# Generating image for seed 150/1000 ...
# Generating image for seed 151/1000 ...
# Generating image for seed 152/1000 ...
# Generating image for seed 153/1000 ...
# Generating image for seed 154/1000 ...
# Generating image for seed 155/1000 ...
# Generating image for seed 156/1000 ...
# Generating image for seed 157/1000 ...
# Generating image for seed 158/1000 ...
# Generating image for seed 159/1000 ...
# Generating image for seed 160/1000 ...
# Generating image for seed 161/1000 ...
# Generating image for seed 162/1000 ...
# Generating image for seed 163/1000 ...
# Generating image for seed 164/1000 ...
# Generating image for seed 165/1000 ...
# Generating image for seed 166/1000 ...
# Generating image for seed 167/1000 ...
# Generating image for seed 168/1000 ...
# Generating image for seed 169/1000 ...
# Generating image for seed 170/1000 ...
# Generating image for seed 171/1000 ...
# Generating image for seed 172/1000 ...
# Generating image for seed 173/1000 ...
# Generating image for seed 174/1000 ...
# Generating image for seed 175/1000 ...
# Generating image for seed 176/1000 ...
# Generating image for seed 177/1000 ...
# Generating image for seed 178/1000 ...
# Generating image for seed 179/1000 ...
# Generating image for seed 180/1000 ...
# Generating image for seed 181/1000 ...
# Generating image for seed 182/1000 ...
# Generating image for seed 183/1000 ...
# Generating image for seed 184/1000 ...
# Generating image for seed 185/1000 ...
# Generating image for seed 186/1000 ...
# Generating image for seed 187/1000 ...
# Generating image for seed 188/1000 ...
# Generating image for seed 189/1000 ...
# Generating image for seed 190/1000 ...
# Generating image for seed 191/1000 ...
# Generating image for seed 192/1000 ...
# Generating image for seed 193/1000 ...
# Generating image for seed 194/1000 ...
# Generating image for seed 195/1000 ...
# Generating image for seed 196/1000 ...
# Generating image for seed 197/1000 ...
# Generating image for seed 198/1000 ...
# Generating image for seed 199/1000 ...
# Generating image for seed 200/1000 ...
# Generating image for seed 201/1000 ...
# Generating image for seed 202/1000 ...
# Generating image for seed 203/1000 ...
# Generating image for seed 204/1000 ...
# Generating image for seed 205/1000 ...
# Generating image for seed 206/1000 ...
# Generating image for seed 207/1000 ...
# Generating image for seed 208/1000 ...
# Generating image for seed 209/1000 ...
# Generating image for seed 210/1000 ...
# Generating image for seed 211/1000 ...
# Generating image for seed 212/1000 ...
# Generating image for seed 213/1000 ...
# Generating image for seed 214/1000 ...
# Generating image for seed 215/1000 ...
# Generating image for seed 216/1000 ...
# Generating image for seed 217/1000 ...
# Generating image for seed 218/1000 ...
# Generating image for seed 219/1000 ...
# Generating image for seed 220/1000 ...
# Generating image for seed 221/1000 ...
# Generating image for seed 222/1000 ...
# Generating image for seed 223/1000 ...
# Generating image for seed 224/1000 ...
# Generating image for seed 225/1000 ...
# Generating image for seed 226/1000 ...
# Generating image for seed 227/1000 ...
# Generating image for seed 228/1000 ...
# Generating image for seed 229/1000 ...
# Generating image for seed 230/1000 ...
# Generating image for seed 231/1000 ...
# Generating image for seed 232/1000 ...
# Generating image for seed 233/1000 ...
# Generating image for seed 234/1000 ...
# Generating image for seed 235/1000 ...
# Generating image for seed 236/1000 ...
# Generating image for seed 237/1000 ...
# Generating image for seed 238/1000 ...
# Generating image for seed 239/1000 ...
# Generating image for seed 240/1000 ...
# Generating image for seed 241/1000 ...
# Generating image for seed 242/1000 ...
# Generating image for seed 243/1000 ...
# Generating image for seed 244/1000 ...
# Generating image for seed 245/1000 ...
# Generating image for seed 246/1000 ...
# Generating image for seed 247/1000 ...
# Generating image for seed 248/1000 ...
# Generating image for seed 249/1000 ...
# Generating image for seed 250/1000 ...
# Generating image for seed 251/1000 ...
# Generating image for seed 252/1000 ...
# Generating image for seed 253/1000 ...
# Generating image for seed 254/1000 ...
# Generating image for seed 255/1000 ...
# Generating image for seed 256/1000 ...
# Generating image for seed 257/1000 ...
# Generating image for seed 258/1000 ...
# Generating image for seed 259/1000 ...
# Generating image for seed 260/1000 ...
# Generating image for seed 261/1000 ...
# Generating image for seed 262/1000 ...
# Generating image for seed 263/1000 ...
# Generating image for seed 264/1000 ...
# Generating image for seed 265/1000 ...
# Generating image for seed 266/1000 ...
# Generating image for seed 267/1000 ...
# Generating image for seed 268/1000 ...
# Generating image for seed 269/1000 ...
# Generating image for seed 270/1000 ...
# Generating image for seed 271/1000 ...
# Generating image for seed 272/1000 ...
# Generating image for seed 273/1000 ...
# Generating image for seed 274/1000 ...
# Generating image for seed 275/1000 ...
# Generating image for seed 276/1000 ...
# Generating image for seed 277/1000 ...
# Generating image for seed 278/1000 ...
# Generating image for seed 279/1000 ...
# Generating image for seed 280/1000 ...
# Generating image for seed 281/1000 ...
# Generating image for seed 282/1000 ...
# Generating image for seed 283/1000 ...
# Generating image for seed 284/1000 ...
# Generating image for seed 285/1000 ...
# Generating image for seed 286/1000 ...
# Generating image for seed 287/1000 ...
# Generating image for seed 288/1000 ...
# Generating image for seed 289/1000 ...
# Generating image for seed 290/1000 ...
# Generating image for seed 291/1000 ...
# Generating image for seed 292/1000 ...
# Generating image for seed 293/1000 ...
# Generating image for seed 294/1000 ...
# Generating image for seed 295/1000 ...
# Generating image for seed 296/1000 ...
# Generating image for seed 297/1000 ...
# Generating image for seed 298/1000 ...
# Generating image for seed 299/1000 ...
# Generating image for seed 300/1000 ...
# Generating image for seed 301/1000 ...
# Generating image for seed 302/1000 ...
# Generating image for seed 303/1000 ...
# Generating image for seed 304/1000 ...
# Generating image for seed 305/1000 ...
# Generating image for seed 306/1000 ...
# Generating image for seed 307/1000 ...
# Generating image for seed 308/1000 ...
# Generating image for seed 309/1000 ...
# Generating image for seed 310/1000 ...
# Generating image for seed 311/1000 ...
# Generating image for seed 312/1000 ...
# Generating image for seed 313/1000 ...
# Generating image for seed 314/1000 ...
# Generating image for seed 315/1000 ...
# Generating image for seed 316/1000 ...
# Generating image for seed 317/1000 ...
# Generating image for seed 318/1000 ...
# Generating image for seed 319/1000 ...
# Generating image for seed 320/1000 ...
# Generating image for seed 321/1000 ...
# Generating image for seed 322/1000 ...
# Generating image for seed 323/1000 ...
# Generating image for seed 324/1000 ...
# Generating image for seed 325/1000 ...
# Generating image for seed 326/1000 ...
# Generating image for seed 327/1000 ...
# Generating image for seed 328/1000 ...
# Generating image for seed 329/1000 ...
# Generating image for seed 330/1000 ...
# Generating image for seed 331/1000 ...
# Generating image for seed 332/1000 ...
# Generating image for seed 333/1000 ...
# Generating image for seed 334/1000 ...
# Generating image for seed 335/1000 ...
# Generating image for seed 336/1000 ...
# Generating image for seed 337/1000 ...
# Generating image for seed 338/1000 ...
# Generating image for seed 339/1000 ...
# Generating image for seed 340/1000 ...
# Generating image for seed 341/1000 ...
# Generating image for seed 342/1000 ...
# Generating image for seed 343/1000 ...
# Generating image for seed 344/1000 ...
# Generating image for seed 345/1000 ...
# Generating image for seed 346/1000 ...
# Generating image for seed 347/1000 ...
# Generating image for seed 348/1000 ...
# Generating image for seed 349/1000 ...
# Generating image for seed 350/1000 ...
# Generating image for seed 351/1000 ...
# Generating image for seed 352/1000 ...
# Generating image for seed 353/1000 ...
# Generating image for seed 354/1000 ...
# Generating image for seed 355/1000 ...
# Generating image for seed 356/1000 ...
# Generating image for seed 357/1000 ...
# Generating image for seed 358/1000 ...
# Generating image for seed 359/1000 ...
# Generating image for seed 360/1000 ...
# Generating image for seed 361/1000 ...
# Generating image for seed 362/1000 ...
# Generating image for seed 363/1000 ...
# Generating image for seed 364/1000 ...
# Generating image for seed 365/1000 ...
# Generating image for seed 366/1000 ...
# Generating image for seed 367/1000 ...
# Generating image for seed 368/1000 ...
# Generating image for seed 369/1000 ...
# Generating image for seed 370/1000 ...
# Generating image for seed 371/1000 ...
# Generating image for seed 372/1000 ...
# Generating image for seed 373/1000 ...
# Generating image for seed 374/1000 ...
# Generating image for seed 375/1000 ...
# Generating image for seed 376/1000 ...
# Generating image for seed 377/1000 ...
# Generating image for seed 378/1000 ...
# Generating image for seed 379/1000 ...
# Generating image for seed 380/1000 ...
# Generating image for seed 381/1000 ...
# Generating image for seed 382/1000 ...
# Generating image for seed 383/1000 ...
# Generating image for seed 384/1000 ...
# Generating image for seed 385/1000 ...
# Generating image for seed 386/1000 ...
# Generating image for seed 387/1000 ...
# Generating image for seed 388/1000 ...
# Generating image for seed 389/1000 ...
# Generating image for seed 390/1000 ...
# Generating image for seed 391/1000 ...
# Generating image for seed 392/1000 ...
# Generating image for seed 393/1000 ...
# Generating image for seed 394/1000 ...
# Generating image for seed 395/1000 ...
# Generating image for seed 396/1000 ...
# Generating image for seed 397/1000 ...
# Generating image for seed 398/1000 ...
# Generating image for seed 399/1000 ...
# Generating image for seed 400/1000 ...
# Generating image for seed 401/1000 ...
# Generating image for seed 402/1000 ...
# Generating image for seed 403/1000 ...
# Generating image for seed 404/1000 ...
# Generating image for seed 405/1000 ...
# Generating image for seed 406/1000 ...
# Generating image for seed 407/1000 ...
# Generating image for seed 408/1000 ...
# Generating image for seed 409/1000 ...
# Generating image for seed 410/1000 ...
# Generating image for seed 411/1000 ...
# Generating image for seed 412/1000 ...
# Generating image for seed 413/1000 ...
# Generating image for seed 414/1000 ...
# Generating image for seed 415/1000 ...
# Generating image for seed 416/1000 ...
# Generating image for seed 417/1000 ...
# Generating image for seed 418/1000 ...
# Generating image for seed 419/1000 ...
# Generating image for seed 420/1000 ...
# Generating image for seed 421/1000 ...
# Generating image for seed 422/1000 ...
# Generating image for seed 423/1000 ...
# Generating image for seed 424/1000 ...
# Generating image for seed 425/1000 ...
# Generating image for seed 426/1000 ...
# Generating image for seed 427/1000 ...
# Generating image for seed 428/1000 ...
# Generating image for seed 429/1000 ...
# Generating image for seed 430/1000 ...
# Generating image for seed 431/1000 ...
# Generating image for seed 432/1000 ...
# Generating image for seed 433/1000 ...
# Generating image for seed 434/1000 ...
# Generating image for seed 435/1000 ...
# Generating image for seed 436/1000 ...
# Generating image for seed 437/1000 ...
# Generating image for seed 438/1000 ...
# Generating image for seed 439/1000 ...
# Generating image for seed 440/1000 ...
# Generating image for seed 441/1000 ...
# Generating image for seed 442/1000 ...
# Generating image for seed 443/1000 ...
# Generating image for seed 444/1000 ...
# Generating image for seed 445/1000 ...
# Generating image for seed 446/1000 ...
# Generating image for seed 447/1000 ...
# Generating image for seed 448/1000 ...
# Generating image for seed 449/1000 ...
# Generating image for seed 450/1000 ...
# Generating image for seed 451/1000 ...
# Generating image for seed 452/1000 ...
# Generating image for seed 453/1000 ...
# Generating image for seed 454/1000 ...
# Generating image for seed 455/1000 ...
# Generating image for seed 456/1000 ...
# Generating image for seed 457/1000 ...
# Generating image for seed 458/1000 ...
# Generating image for seed 459/1000 ...
# Generating image for seed 460/1000 ...
# Generating image for seed 461/1000 ...
# Generating image for seed 462/1000 ...
# Generating image for seed 463/1000 ...
# Generating image for seed 464/1000 ...
# Generating image for seed 465/1000 ...
# Generating image for seed 466/1000 ...
# Generating image for seed 467/1000 ...
# Generating image for seed 468/1000 ...
# Generating image for seed 469/1000 ...
# Generating image for seed 470/1000 ...
# Generating image for seed 471/1000 ...
# Generating image for seed 472/1000 ...
# Generating image for seed 473/1000 ...
# Generating image for seed 474/1000 ...
# Generating image for seed 475/1000 ...
# Generating image for seed 476/1000 ...
# Generating image for seed 477/1000 ...
# Generating image for seed 478/1000 ...
# Generating image for seed 479/1000 ...
# Generating image for seed 480/1000 ...
# Generating image for seed 481/1000 ...
# Generating image for seed 482/1000 ...
# Generating image for seed 483/1000 ...
# Generating image for seed 484/1000 ...
# Generating image for seed 485/1000 ...
# Generating image for seed 486/1000 ...
# Generating image for seed 487/1000 ...
# Generating image for seed 488/1000 ...
# Generating image for seed 489/1000 ...
# Generating image for seed 490/1000 ...
# Generating image for seed 491/1000 ...
# Generating image for seed 492/1000 ...
# Generating image for seed 493/1000 ...
# Generating image for seed 494/1000 ...
# Generating image for seed 495/1000 ...
# Generating image for seed 496/1000 ...
# Generating image for seed 497/1000 ...
# Generating image for seed 498/1000 ...
# Generating image for seed 499/1000 ...
# Generating image for seed 500/1000 ...
# Generating image for seed 501/1000 ...
# Generating image for seed 502/1000 ...
# Generating image for seed 503/1000 ...
# Generating image for seed 504/1000 ...
# Generating image for seed 505/1000 ...
# Generating image for seed 506/1000 ...
# Generating image for seed 507/1000 ...
# Generating image for seed 508/1000 ...
# Generating image for seed 509/1000 ...
# Generating image for seed 510/1000 ...
# Generating image for seed 511/1000 ...
# Generating image for seed 512/1000 ...
# Generating image for seed 513/1000 ...
# Generating image for seed 514/1000 ...
# Generating image for seed 515/1000 ...
# Generating image for seed 516/1000 ...
# Generating image for seed 517/1000 ...
# Generating image for seed 518/1000 ...
# Generating image for seed 519/1000 ...
# Generating image for seed 520/1000 ...
# Generating image for seed 521/1000 ...
# Generating image for seed 522/1000 ...
# Generating image for seed 523/1000 ...
# Generating image for seed 524/1000 ...
# Generating image for seed 525/1000 ...
# Generating image for seed 526/1000 ...
# Generating image for seed 527/1000 ...
# Generating image for seed 528/1000 ...
# Generating image for seed 529/1000 ...
# Generating image for seed 530/1000 ...
# Generating image for seed 531/1000 ...
# Generating image for seed 532/1000 ...
# Generating image for seed 533/1000 ...
# Generating image for seed 534/1000 ...
# Generating image for seed 535/1000 ...
# Generating image for seed 536/1000 ...
# Generating image for seed 537/1000 ...
# Generating image for seed 538/1000 ...
# Generating image for seed 539/1000 ...
# Generating image for seed 540/1000 ...
# Generating image for seed 541/1000 ...
# Generating image for seed 542/1000 ...
# Generating image for seed 543/1000 ...
# Generating image for seed 544/1000 ...
# Generating image for seed 545/1000 ...
# Generating image for seed 546/1000 ...
# Generating image for seed 547/1000 ...
# Generating image for seed 548/1000 ...
# Generating image for seed 549/1000 ...
# Generating image for seed 550/1000 ...
# Generating image for seed 551/1000 ...
# Generating image for seed 552/1000 ...
# Generating image for seed 553/1000 ...
# Generating image for seed 554/1000 ...
# Generating image for seed 555/1000 ...
# Generating image for seed 556/1000 ...
# Generating image for seed 557/1000 ...
# Generating image for seed 558/1000 ...
# Generating image for seed 559/1000 ...
# Generating image for seed 560/1000 ...
# Generating image for seed 561/1000 ...
# Generating image for seed 562/1000 ...
# Generating image for seed 563/1000 ...
# Generating image for seed 564/1000 ...
# Generating image for seed 565/1000 ...
# Generating image for seed 566/1000 ...
# Generating image for seed 567/1000 ...
# Generating image for seed 568/1000 ...
# Generating image for seed 569/1000 ...
# Generating image for seed 570/1000 ...
# Generating image for seed 571/1000 ...
# Generating image for seed 572/1000 ...
# Generating image for seed 573/1000 ...
# Generating image for seed 574/1000 ...
# Generating image for seed 575/1000 ...
# Generating image for seed 576/1000 ...
# Generating image for seed 577/1000 ...
# Generating image for seed 578/1000 ...
# Generating image for seed 579/1000 ...
# Generating image for seed 580/1000 ...
# Generating image for seed 581/1000 ...
# Generating image for seed 582/1000 ...
# Generating image for seed 583/1000 ...
# Generating image for seed 584/1000 ...
# Generating image for seed 585/1000 ...
# Generating image for seed 586/1000 ...
# Generating image for seed 587/1000 ...
# Generating image for seed 588/1000 ...
# Generating image for seed 589/1000 ...
# Generating image for seed 590/1000 ...
# Generating image for seed 591/1000 ...
# Generating image for seed 592/1000 ...
# Generating image for seed 593/1000 ...
# Generating image for seed 594/1000 ...
# Generating image for seed 595/1000 ...
# Generating image for seed 596/1000 ...
# Generating image for seed 597/1000 ...
# Generating image for seed 598/1000 ...
# Generating image for seed 599/1000 ...
# Generating image for seed 600/1000 ...
# Generating image for seed 601/1000 ...
# Generating image for seed 602/1000 ...
# Generating image for seed 603/1000 ...
# Generating image for seed 604/1000 ...
# Generating image for seed 605/1000 ...
# Generating image for seed 606/1000 ...
# Generating image for seed 607/1000 ...
# Generating image for seed 608/1000 ...
# Generating image for seed 609/1000 ...
# Generating image for seed 610/1000 ...
# Generating image for seed 611/1000 ...
# Generating image for seed 612/1000 ...
# Generating image for seed 613/1000 ...
# Generating image for seed 614/1000 ...
# Generating image for seed 615/1000 ...
# Generating image for seed 616/1000 ...
# Generating image for seed 617/1000 ...
# Generating image for seed 618/1000 ...
# Generating image for seed 619/1000 ...
# Generating image for seed 620/1000 ...
# Generating image for seed 621/1000 ...
# Generating image for seed 622/1000 ...
# Generating image for seed 623/1000 ...
# Generating image for seed 624/1000 ...
# Generating image for seed 625/1000 ...
# Generating image for seed 626/1000 ...
# Generating image for seed 627/1000 ...
# Generating image for seed 628/1000 ...
# Generating image for seed 629/1000 ...
# Generating image for seed 630/1000 ...
# Generating image for seed 631/1000 ...
# Generating image for seed 632/1000 ...
# Generating image for seed 633/1000 ...
# Generating image for seed 634/1000 ...
# Generating image for seed 635/1000 ...
# Generating image for seed 636/1000 ...
# Generating image for seed 637/1000 ...
# Generating image for seed 638/1000 ...
# Generating image for seed 639/1000 ...
# Generating image for seed 640/1000 ...
# Generating image for seed 641/1000 ...
# Generating image for seed 642/1000 ...
# Generating image for seed 643/1000 ...
# Generating image for seed 644/1000 ...
# Generating image for seed 645/1000 ...
# Generating image for seed 646/1000 ...
# Generating image for seed 647/1000 ...
# Generating image for seed 648/1000 ...
# Generating image for seed 649/1000 ...
# Generating image for seed 650/1000 ...
# Generating image for seed 651/1000 ...
# Generating image for seed 652/1000 ...
# Generating image for seed 653/1000 ...
# Generating image for seed 654/1000 ...
# Generating image for seed 655/1000 ...
# Generating image for seed 656/1000 ...
# Generating image for seed 657/1000 ...
# Generating image for seed 658/1000 ...
# Generating image for seed 659/1000 ...
# Generating image for seed 660/1000 ...
# Generating image for seed 661/1000 ...
# Generating image for seed 662/1000 ...
# Generating image for seed 663/1000 ...
# Generating image for seed 664/1000 ...
# Generating image for seed 665/1000 ...
# Generating image for seed 666/1000 ...
# Generating image for seed 667/1000 ...
# Generating image for seed 668/1000 ...
# Generating image for seed 669/1000 ...
# Generating image for seed 670/1000 ...
# Generating image for seed 671/1000 ...
# Generating image for seed 672/1000 ...
# Generating image for seed 673/1000 ...
# Generating image for seed 674/1000 ...
# Generating image for seed 675/1000 ...
# Generating image for seed 676/1000 ...
# Generating image for seed 677/1000 ...
# Generating image for seed 678/1000 ...
# Generating image for seed 679/1000 ...
# Generating image for seed 680/1000 ...
# Generating image for seed 681/1000 ...
# Generating image for seed 682/1000 ...
# Generating image for seed 683/1000 ...
# Generating image for seed 684/1000 ...
# Generating image for seed 685/1000 ...
# Generating image for seed 686/1000 ...
# Generating image for seed 687/1000 ...
# Generating image for seed 688/1000 ...
# Generating image for seed 689/1000 ...
# Generating image for seed 690/1000 ...
# Generating image for seed 691/1000 ...
# Generating image for seed 692/1000 ...
# Generating image for seed 693/1000 ...
# Generating image for seed 694/1000 ...
# Generating image for seed 695/1000 ...
# Generating image for seed 696/1000 ...
# Generating image for seed 697/1000 ...
# Generating image for seed 698/1000 ...
# Generating image for seed 699/1000 ...
# Generating image for seed 700/1000 ...
# Generating image for seed 701/1000 ...
# Generating image for seed 702/1000 ...
# Generating image for seed 703/1000 ...
# Generating image for seed 704/1000 ...
# Generating image for seed 705/1000 ...
# Generating image for seed 706/1000 ...
# Generating image for seed 707/1000 ...
# Generating image for seed 708/1000 ...
# Generating image for seed 709/1000 ...
# Generating image for seed 710/1000 ...
# Generating image for seed 711/1000 ...
# Generating image for seed 712/1000 ...
# Generating image for seed 713/1000 ...
# Generating image for seed 714/1000 ...
# Generating image for seed 715/1000 ...
# Generating image for seed 716/1000 ...
# Generating image for seed 717/1000 ...
# Generating image for seed 718/1000 ...
# Generating image for seed 719/1000 ...
# Generating image for seed 720/1000 ...
# Generating image for seed 721/1000 ...
# Generating image for seed 722/1000 ...
# Generating image for seed 723/1000 ...
# Generating image for seed 724/1000 ...
# Generating image for seed 725/1000 ...
# Generating image for seed 726/1000 ...
# Generating image for seed 727/1000 ...
# Generating image for seed 728/1000 ...
# Generating image for seed 729/1000 ...
# Generating image for seed 730/1000 ...
# Generating image for seed 731/1000 ...
# Generating image for seed 732/1000 ...
# Generating image for seed 733/1000 ...
# Generating image for seed 734/1000 ...
# Generating image for seed 735/1000 ...
# Generating image for seed 736/1000 ...
# Generating image for seed 737/1000 ...
# Generating image for seed 738/1000 ...
# Generating image for seed 739/1000 ...
# Generating image for seed 740/1000 ...
# Generating image for seed 741/1000 ...
# Generating image for seed 742/1000 ...
# Generating image for seed 743/1000 ...
# Generating image for seed 744/1000 ...
# Generating image for seed 745/1000 ...
# Generating image for seed 746/1000 ...
# Generating image for seed 747/1000 ...
# Generating image for seed 748/1000 ...
# Generating image for seed 749/1000 ...
# Generating image for seed 750/1000 ...
# Generating image for seed 751/1000 ...
# Generating image for seed 752/1000 ...
# Generating image for seed 753/1000 ...
# Generating image for seed 754/1000 ...
# Generating image for seed 755/1000 ...
# Generating image for seed 756/1000 ...
# Generating image for seed 757/1000 ...
# Generating image for seed 758/1000 ...
# Generating image for seed 759/1000 ...
# Generating image for seed 760/1000 ...
# Generating image for seed 761/1000 ...
# Generating image for seed 762/1000 ...
# Generating image for seed 763/1000 ...
# Generating image for seed 764/1000 ...
# Generating image for seed 765/1000 ...
# Generating image for seed 766/1000 ...
# Generating image for seed 767/1000 ...
# Generating image for seed 768/1000 ...
# Generating image for seed 769/1000 ...
# Generating image for seed 770/1000 ...
# Generating image for seed 771/1000 ...
# Generating image for seed 772/1000 ...
# Generating image for seed 773/1000 ...
# Generating image for seed 774/1000 ...
# Generating image for seed 775/1000 ...
# Generating image for seed 776/1000 ...
# Generating image for seed 777/1000 ...
# Generating image for seed 778/1000 ...
# Generating image for seed 779/1000 ...
# Generating image for seed 780/1000 ...
# Generating image for seed 781/1000 ...
# Generating image for seed 782/1000 ...
# Generating image for seed 783/1000 ...
# Generating image for seed 784/1000 ...
# Generating image for seed 785/1000 ...
# Generating image for seed 786/1000 ...
# Generating image for seed 787/1000 ...
# Generating image for seed 788/1000 ...
# Generating image for seed 789/1000 ...
# Generating image for seed 790/1000 ...
# Generating image for seed 791/1000 ...
# Generating image for seed 792/1000 ...
# Generating image for seed 793/1000 ...
# Generating image for seed 794/1000 ...
# Generating image for seed 795/1000 ...
# Generating image for seed 796/1000 ...
# Generating image for seed 797/1000 ...
# Generating image for seed 798/1000 ...
# Generating image for seed 799/1000 ...
# Generating image for seed 800/1000 ...
# Generating image for seed 801/1000 ...
# Generating image for seed 802/1000 ...
# Generating image for seed 803/1000 ...
# Generating image for seed 804/1000 ...
# Generating image for seed 805/1000 ...
# Generating image for seed 806/1000 ...
# Generating image for seed 807/1000 ...
# Generating image for seed 808/1000 ...
# Generating image for seed 809/1000 ...
# Generating image for seed 810/1000 ...
# Generating image for seed 811/1000 ...
# Generating image for seed 812/1000 ...
# Generating image for seed 813/1000 ...
# Generating image for seed 814/1000 ...
# Generating image for seed 815/1000 ...
# Generating image for seed 816/1000 ...
# Generating image for seed 817/1000 ...
# Generating image for seed 818/1000 ...
# Generating image for seed 819/1000 ...
# Generating image for seed 820/1000 ...
# Generating image for seed 821/1000 ...
# Generating image for seed 822/1000 ...
# Generating image for seed 823/1000 ...
# Generating image for seed 824/1000 ...
# Generating image for seed 825/1000 ...
# Generating image for seed 826/1000 ...
# Generating image for seed 827/1000 ...
# Generating image for seed 828/1000 ...
# Generating image for seed 829/1000 ...
# Generating image for seed 830/1000 ...
# Generating image for seed 831/1000 ...
# Generating image for seed 832/1000 ...
# Generating image for seed 833/1000 ...
# Generating image for seed 834/1000 ...
# Generating image for seed 835/1000 ...
# Generating image for seed 836/1000 ...
# Generating image for seed 837/1000 ...
# Generating image for seed 838/1000 ...
# Generating image for seed 839/1000 ...
# Generating image for seed 840/1000 ...
# Generating image for seed 841/1000 ...
# Generating image for seed 842/1000 ...
# Generating image for seed 843/1000 ...
# Generating image for seed 844/1000 ...
# Generating image for seed 845/1000 ...
# Generating image for seed 846/1000 ...
# Generating image for seed 847/1000 ...
# Generating image for seed 848/1000 ...
# Generating image for seed 849/1000 ...
# Generating image for seed 850/1000 ...
# Generating image for seed 851/1000 ...
# Generating image for seed 852/1000 ...
# Generating image for seed 853/1000 ...
# Generating image for seed 854/1000 ...
# Generating image for seed 855/1000 ...
# Generating image for seed 856/1000 ...
# Generating image for seed 857/1000 ...
# Generating image for seed 858/1000 ...
# Generating image for seed 859/1000 ...
# Generating image for seed 860/1000 ...
# Generating image for seed 861/1000 ...
# Generating image for seed 862/1000 ...
# Generating image for seed 863/1000 ...
# Generating image for seed 864/1000 ...
# Generating image for seed 865/1000 ...
# Generating image for seed 866/1000 ...
# Generating image for seed 867/1000 ...
# Generating image for seed 868/1000 ...
# Generating image for seed 869/1000 ...
# Generating image for seed 870/1000 ...
# Generating image for seed 871/1000 ...
# Generating image for seed 872/1000 ...
# Generating image for seed 873/1000 ...
# Generating image for seed 874/1000 ...
# Generating image for seed 875/1000 ...
# Generating image for seed 876/1000 ...
# Generating image for seed 877/1000 ...
# Generating image for seed 878/1000 ...
# Generating image for seed 879/1000 ...
# Generating image for seed 880/1000 ...
# Generating image for seed 881/1000 ...
# Generating image for seed 882/1000 ...
# Generating image for seed 883/1000 ...
# Generating image for seed 884/1000 ...
# Generating image for seed 885/1000 ...
# Generating image for seed 886/1000 ...
# Generating image for seed 887/1000 ...
# Generating image for seed 888/1000 ...
# Generating image for seed 889/1000 ...
# Generating image for seed 890/1000 ...
# Generating image for seed 891/1000 ...
# Generating image for seed 892/1000 ...
# Generating image for seed 893/1000 ...
# Generating image for seed 894/1000 ...
# Generating image for seed 895/1000 ...
# Generating image for seed 896/1000 ...
# Generating image for seed 897/1000 ...
# Generating image for seed 898/1000 ...
# Generating image for seed 899/1000 ...
# Generating image for seed 900/1000 ...
# Generating image for seed 901/1000 ...
# Generating image for seed 902/1000 ...
# Generating image for seed 903/1000 ...
# Generating image for seed 904/1000 ...
# Generating image for seed 905/1000 ...
# Generating image for seed 906/1000 ...
# Generating image for seed 907/1000 ...
# Generating image for seed 908/1000 ...
# Generating image for seed 909/1000 ...
# Generating image for seed 910/1000 ...
# Generating image for seed 911/1000 ...
# Generating image for seed 912/1000 ...
# Generating image for seed 913/1000 ...
# Generating image for seed 914/1000 ...
# Generating image for seed 915/1000 ...
# Generating image for seed 916/1000 ...
# Generating image for seed 917/1000 ...
# Generating image for seed 918/1000 ...
# Generating image for seed 919/1000 ...
# Generating image for seed 920/1000 ...
# Generating image for seed 921/1000 ...
# Generating image for seed 922/1000 ...
# Generating image for seed 923/1000 ...
# Generating image for seed 924/1000 ...
# Generating image for seed 925/1000 ...
# Generating image for seed 926/1000 ...
# Generating image for seed 927/1000 ...
# Generating image for seed 928/1000 ...
# Generating image for seed 929/1000 ...
# Generating image for seed 930/1000 ...
# Generating image for seed 931/1000 ...
# Generating image for seed 932/1000 ...
# Generating image for seed 933/1000 ...
# Generating image for seed 934/1000 ...
# Generating image for seed 935/1000 ...
# Generating image for seed 936/1000 ...
# Generating image for seed 937/1000 ...
# Generating image for seed 938/1000 ...
# Generating image for seed 939/1000 ...
# Generating image for seed 940/1000 ...
# Generating image for seed 941/1000 ...
# Generating image for seed 942/1000 ...
# Generating image for seed 943/1000 ...
# Generating image for seed 944/1000 ...
# Generating image for seed 945/1000 ...
# Generating image for seed 946/1000 ...
# Generating image for seed 947/1000 ...
# Generating image for seed 948/1000 ...
# Generating image for seed 949/1000 ...
# Generating image for seed 950/1000 ...
# Generating image for seed 951/1000 ...
# Generating image for seed 952/1000 ...
# Generating image for seed 953/1000 ...
# Generating image for seed 954/1000 ...
# Generating image for seed 955/1000 ...
# Generating image for seed 956/1000 ...
# Generating image for seed 957/1000 ...
# Generating image for seed 958/1000 ...
# Generating image for seed 959/1000 ...
# Generating image for seed 960/1000 ...
# Generating image for seed 961/1000 ...
# Generating image for seed 962/1000 ...
# Generating image for seed 963/1000 ...
# Generating image for seed 964/1000 ...
# Generating image for seed 965/1000 ...
# Generating image for seed 966/1000 ...
# Generating image for seed 967/1000 ...
# Generating image for seed 968/1000 ...
# Generating image for seed 969/1000 ...
# Generating image for seed 970/1000 ...
# Generating image for seed 971/1000 ...
# Generating image for seed 972/1000 ...
# Generating image for seed 973/1000 ...
# Generating image for seed 974/1000 ...
# Generating image for seed 975/1000 ...
# Generating image for seed 976/1000 ...
# Generating image for seed 977/1000 ...
# Generating image for seed 978/1000 ...
# Generating image for seed 979/1000 ...
# Generating image for seed 980/1000 ...
# Generating image for seed 981/1000 ...

# %% [markdown]
# ffmpeg -r 30 -i image%d.png -vcodec mpeg4 -y movie.mp4

# %%
# !ffmpeg -r 30 -i image%d.png -vcodec mpeg4 -y movie.mp4
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# [image2 @ 0x556468096000] Could find no file with path 'image%d.png' and index in the range 0-4
# image%d.png: No such file or directory
